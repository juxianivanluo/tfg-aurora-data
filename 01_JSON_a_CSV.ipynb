# %% [markdown]
# ## 1. Carga de datos
#
# Lectura e importación del fichero JSON en bruto para iniciar el proceso de aplanado (*flattening*) y estructuración de los datos.

# %%
import json
import pandas as pd
from IPython.display import display


pd.set_option('display.max_columns', None)

with open('user_data.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

for user in data:
    user.setdefault("userId", "unknown")       # asigna 'unknown' solo si no existe

df = pd.json_normalize(data).set_index('userId')
display(df.head())
display(df.shape)
# Out:
#                                                                                          consumptions  \
# userId
# c48be05f22d807690af96730960b5741b9e0cc2b66afecd...  [{'createdAt': {'_seconds': 1739660708, '_nano...
# 459534a68d4f9828fdf2c7ab7346f7af93b3548dcca0737...                                                 []
# bb082d002acd3fe83a7f3b04c14ce91a923d2e39926f238...                                                 []
# b5135f676cb3a6c28d5c496d20a31eda5efd94f59307962...                                                 []
# af553187df49982d43890043fb6dec88529276746f1ea81...  [{'createdAt': {'_seconds': 1742166304, '_nano...
#
#                                                    consumptionSummaries  \
# userId
# c48be05f22d807690af96730960b5741b9e0cc2b66afecd...                   []
# 459534a68d4f9828fdf2c7ab7346f7af93b3548dcca0737...                   []
# bb082d002acd3fe83a7f3b04c14ce91a923d2e39926f238...                   []
# b5135f676cb3a6c28d5c496d20a31eda5efd94f59307962...                   []
# af553187df49982d43890043fb6dec88529276746f1ea81...                   []
#
#                                                    countryCode    city  \
# userId
# c48be05f22d807690af96730960b5741b9e0cc2b66afecd...          ES  Madrid
# 459534a68d4f9828fdf2c7ab7346f7af93b3548dcca0737...          EU    None
# bb082d002acd3fe83a7f3b04c14ce91a923d2e39926f238...          ES  Madrid
# b5135f676cb3a6c28d5c496d20a31eda5efd94f59307962...          LV    None
# af553187df49982d43890043fb6dec88529276746f1ea81...          ES    None
#
#                                                     yearOfBirth  gender  \
# userId
# c48be05f22d807690af96730960b5741b9e0cc2b66afecd...       2005.0  female
# 459534a68d4f9828fdf2c7ab7346f7af93b3548dcca0737...       1995.0  female
# bb082d002acd3fe83a7f3b04c14ce91a923d2e39926f238...       2024.0    male
# b5135f676cb3a6c28d5c496d20a31eda5efd94f59307962...       2013.0   other
# af553187df49982d43890043fb6dec88529276746f1ea81...       2005.0    male
#
#                                                    homeEnergyLabel  \
# userId
# c48be05f22d807690af96730960b5741b9e0cc2b66afecd...            None
# 459534a68d4f9828fdf2c7ab7346f7af93b3548dcca0737...            None
# bb082d002acd3fe83a7f3b04c14ce91a923d2e39926f238...          unsure
# b5135f676cb3a6c28d5c496d20a31eda5efd94f59307962...            None
# af553187df49982d43890043fb6dec88529276746f1ea81...            None
#
#                                                                    householdProfile
# userId
# c48be05f22d807690af96730960b5741b9e0cc2b66afecd...                             None
# 459534a68d4f9828fdf2c7ab7346f7af93b3548dcca0737...                             None
# bb082d002acd3fe83a7f3b04c14ce91a923d2e39926f238...  workersOrStudentsOutsideTheHome
# b5135f676cb3a6c28d5c496d20a31eda5efd94f59307962...                             None
# af553187df49982d43890043fb6dec88529276746f1ea81...                             None
# (1470, 8)

# %% [markdown]
# ## 2. Aplanado de datos y exportación a CSV y XLSX
#
# Aplanamos los datos del fichero JSON (habiendo analizado previamente su estructura estructurada) para su posterior conversión a los formatos CSV y XLSX.

# %%
records = []

for user in data:
    # Campos comunes del usuario
    user_fields = {
        "userId": user.get("userId", "unknown"),
        "city": user.get("city"),
        "country": user.get("countryCode"),
        "gender": user.get("gender"),
        "yearOfBirth": user.get("yearOfBirth"),
        "homeEnergyLabel": user.get("homeEnergyLabel"),
        "householdProfile": user.get("householdProfile"),
    }

    for consumption in user.get("consumptions", []):
        # Mezclamos los campos del usuario con el diccionario del consumo (aún sin aplanar)
        combined = {**user_fields, **consumption}
        records.append(combined)

# json_normalize aplana automáticamente cualquier diccionario/lista anidado dentro de cada consumo
df = pd.json_normalize(records)

# Exportación
df.to_csv('consumptions.csv', index=False)
df.to_excel('consumptions.xlsx', index=False)
display(df.head())
display(df.shape)
# Out:
#                                               userId    city country  gender  \
# 0  c48be05f22d807690af96730960b5741b9e0cc2b66afec...  Madrid      ES  female
# 1  c48be05f22d807690af96730960b5741b9e0cc2b66afec...  Madrid      ES  female
# 2  c48be05f22d807690af96730960b5741b9e0cc2b66afec...  Madrid      ES  female
# 3  c48be05f22d807690af96730960b5741b9e0cc2b66afec...  Madrid      ES  female
# 4  c48be05f22d807690af96730960b5741b9e0cc2b66afec...  Madrid      ES  female
#
#    yearOfBirth homeEnergyLabel householdProfile        category  value  \
# 0       2005.0            None             None  transportation    7.0
# 1       2005.0            None             None  transportation    7.0
# 2       2005.0            None             None  transportation    7.0
# 3       2005.0            None             None  transportation    7.0
# 4       2005.0            None             None  transportation    7.0
#
#   generatedByRecurringConsumptionId  carbonEmissions  energyExpended version  \
# 0              YrDsWyuBkGQ5gi6ERzOr           0.0952          0.4991   1.1.1
# 1              YrDsWyuBkGQ5gi6ERzOr           0.0952          0.4991   1.1.1
# 2              YrDsWyuBkGQ5gi6ERzOr           0.0952          0.4991   1.1.1
# 3              YrDsWyuBkGQ5gi6ERzOr           0.0952          0.4991   1.1.1
# 4              YrDsWyuBkGQ5gi6ERzOr           0.0952          0.4991   1.1.1
#
#                                        consumptionId  createdAt._seconds  \
# 0  ee2b7f6650f801b7abd053e847e022bd6f3a28a2f5b795...          1739660708
# 1  9c7bc0aef3b7fcd26868e09ed706b75e30bc0f4c98fd8f...          1718921103
# 2  eba1c0679ff1a494bd094f20c9752e0f015f4e6a5f9862...          1723413903
# 3  987508a021ccc619324e1608418cf3112a0e552d6973aa...          1717279503
# 4  208a40da22b22ad24ada1b11a03246bac1def7dc42dea6...          1720476303
#
#    createdAt._nanoseconds  transportation.dateOfTravel._seconds  \
# 0               384000000                          1.739606e+09
# 1               867000000                          1.718870e+09
# 2               558000000                          1.723363e+09
# 3               607000000                          1.717228e+09
# 4               410000000                          1.720425e+09
#
#    transportation.dateOfTravel._nanoseconds transportation.transportationType  \
# 0                                       0.0        metroTramOrUrbanLightTrain
# 1                                       0.0        metroTramOrUrbanLightTrain
# 2                                       0.0        metroTramOrUrbanLightTrain
# 3                                       0.0        metroTramOrUrbanLightTrain
# 4                                       0.0        metroTramOrUrbanLightTrain
#
#   transportation.publicVehicleOccupancy  updatedAt._seconds  \
# 0                                medium        1.739661e+09
# 1                                medium        1.718921e+09
# 2                                medium        1.723414e+09
# 3                                medium        1.717280e+09
# 4                                medium        1.720476e+09
#
#    updatedAt._nanoseconds  transportation.privateVehicleOccupancy  \
# 0             324000000.0                                     NaN
# 1             543000000.0                                     NaN
# 2             234000000.0                                     NaN
# 3             557000000.0                                     NaN
# 4             802000000.0                                     NaN
#
#    electricity.endDate._seconds  electricity.endDate._nanoseconds  \
# 0                           NaN                               NaN
# 1                           NaN                               NaN
# 2                           NaN                               NaN
# 3                           NaN                               NaN
# 4                           NaN                               NaN
#
#    electricity.householdSize  electricity.startDate._seconds  \
# 0                        NaN                             NaN
# 1                        NaN                             NaN
# 2                        NaN                             NaN
# 3                        NaN                             NaN
# 4                        NaN                             NaN
#
#    electricity.startDate._nanoseconds  heating.costs  \
# 0                                 NaN            NaN
# 1                                 NaN            NaN
# 2                                 NaN            NaN
# 3                                 NaN            NaN
# 4                                 NaN            NaN
#
#    heating.endDate._seconds  heating.endDate._nanoseconds heating.heatingFuel  \
# 0                       NaN                           NaN                 NaN
# 1                       NaN                           NaN                 NaN
# 2                       NaN                           NaN                 NaN
# 3                       NaN                           NaN                 NaN
# 4                       NaN                           NaN                 NaN
#
#    heating.householdSize  heating.startDate._seconds  \
# 0                    NaN                         NaN
# 1                    NaN                         NaN
# 2                    NaN                         NaN
# 3                    NaN                         NaN
# 4                    NaN                         NaN
#
#    heating.startDate._nanoseconds  transportation.dateOfTravelEnd._seconds  \
# 0                             NaN                                      NaN
# 1                             NaN                                      NaN
# 2                             NaN                                      NaN
# 3                             NaN                                      NaN
# 4                             NaN                                      NaN
#
#    transportation.dateOfTravelEnd._nanoseconds electricity.electricitySource  \
# 0                                          NaN                           NaN
# 1                                          NaN                           NaN
# 2                                          NaN                           NaN
# 3                                          NaN                           NaN
# 4                                          NaN                           NaN
#
#    electricity.costs  transportation.fuelConsumption  \
# 0                NaN                             NaN
# 1                NaN                             NaN
# 2                NaN                             NaN
# 3                NaN                             NaN
# 4                NaN                             NaN
#
#    electricity.electricityExported generatedByPvInvestmentId  \
# 0                              NaN                       NaN
# 1                              NaN                       NaN
# 2                              NaN                       NaN
# 3                              NaN                       NaN
# 4                              NaN                       NaN
#
#   heating.districtHeatingSource
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# (119124, 43)
